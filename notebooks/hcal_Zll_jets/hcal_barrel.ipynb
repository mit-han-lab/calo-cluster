# %%
from calo_cluster.datasets.hcal_Zll_jets import HCalZllJetsOffsetDataModule
from calo_cluster.evaluation.experiments.base_experiment import BaseExperiment
from calo_cluster.evaluation.experiments.base_offset_experiment import BaseOffsetExperiment
from pathlib import Path 
from calo_cluster.clustering.meanshift import MeanShift
from tqdm.auto import tqdm
from calo_cluster.evaluation.metrics.classification import mIoU
from calo_cluster.evaluation.metrics.instance import PanopticQuality
import numpy as np
import plotly
import plotly.express as px
from calo_cluster.evaluation.utils import get_palette
import pandas as pd

# %%
exp = BaseOffsetExperiment('2nnbuz0n')
# Out:
# run_dir = /global/cscratch1/sd/schuya/calo_cluster/training_outputs/wandb/run-20211104_111517-2nnbuz0n
# no checkpoint name given, using /global/cscratch1/sd/schuya/calo_cluster/training_outputs/hgcal-spvcnn/2nnbuz0n/checkpoints/last.ckpt.
# Global seed set to 1588147245

# %%
events = exp.get_events(split='val', n=100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from tqdm.auto import tqdm
bws = [0.1]
rets = {}
for bw in bws:
    print(f'bw = {bw}')
    clusterer = MeanShift(bandwidth=bw, use_semantic=True, ignore_semantic_labels=(0,), use_gpu=False)
    pq = PanopticQuality(num_classes=2, ignore_index=None, ignore_semantic_labels=(0,))
    for evt in tqdm(events):
        semantic_truth = evt.input_event['hit'].to_numpy()
        evt.pred_instance_labels = clusterer.cluster(embedding=evt.embedding, semantic_labels=semantic_truth)
        pq.add((semantic_truth, evt.pred_instance_labels), (semantic_truth, evt.input_event['trackId'].astype(int).to_numpy()))
    rets[bw] = pq.compute()
    print(f'(bw = {bw}) pq = {rets[bw]}')
# Out:
# bw = 0.1
#   0%|          | 0/100 [00:00<?, ?it/s]
# (bw = 0.1) pq = {'sq': array([-1.       ,  0.9771684]), 'rq': array([-1.        ,  0.74824328]), 'pq': 0.7311596878473545, 'tq': array([-1.       ,  0.6883638]), 'wrq': array([-1.        ,  0.76456428]), 'wpq': 0.7471080527933466, 'wtq': array([-1.        ,  0.76236198])}

# %%
pq = PanopticQuality(num_classes=2, ignore_index=None, ignore_semantic_labels=(0,))
for evt in tqdm(events):
    semantic_truth = evt.input_event['hit'].to_numpy()
    pq.add((semantic_truth, evt.input_event['PFcluster0Id'].to_numpy()), (semantic_truth, evt.input_event['trackId'].astype(int).to_numpy()))
print(f'pq = {pq.compute()}')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# pq = {'sq': array([-1.        ,  0.96114314]), 'rq': array([-1.        ,  0.49444119]), 'pq': 0.4752287599274139, 'tq': array([-1.       ,  0.3767276]), 'wrq': array([-1.        ,  0.62608232]), 'wpq': 0.6017547280707579, 'wtq': array([-1.        ,  0.56395488])}

# %%
events[0].input_event.columns

# %%
n = 15
evt = events[n]
d = {'eta': evt.input_event['eta'], 'phi': evt.input_event['phi'], 'energy': evt.input_event['energy'], 'hit': evt.input_event['hit'], 'id': evt.input_event['trackId'], 'eta_pred': evt.embedding[:,0], 'phi_pred': evt.embedding[:,1]}
plot_df = pd.DataFrame(d)
plot_df['id'] = plot_df['id'].astype(str)
plot_df = plot_df[plot_df['hit'] == 1]

# %%
px.scatter(plot_df, x='eta', y='phi', size='energy', color='id', color_discrete_sequence=get_palette(plot_df['id']))
# Out:
# <div>                            <div id="e167b343-246e-4604-b0f2-f0331c9bcfca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e167b343-246e-4604-b0f2-f0331c9bcfca")) {                    Plotly.newPlot(                        "e167b343-246e-4604-b0f2-f0331c9bcfca",                        [{"hovertemplate":"id=302137<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"302137","marker":{"color":"rgb(214, 0, 0)","size":[0.003629842074587941,0.0],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"302137","orientation":"v","showlegend":true,"type":"scatter","x":[-0.13050001859664917,-0.2174999713897705],"xaxis":"x","y":[-2.050762176513672,-2.0507619380950928],"yaxis":"y"},{"hovertemplate":"id=401032<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"401032","marker":{"color":"rgb(140, 59, 255)","size":[0.5512226819992065],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"401032","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8265000581741333],"xaxis":"x","y":[-1.788962721824646],"yaxis":"y"},{"hovertemplate":"id=359378<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"359378","marker":{"color":"rgb(1, 135, 0)","size":[0.17138375341892242,0.2544173002243042],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"359378","orientation":"v","showlegend":true,"type":"scatter","x":[-0.9135000109672546,-1.000499963760376],"xaxis":"x","y":[2.5743606090545654,2.5743606090545654],"yaxis":"y"},{"hovertemplate":"id=403219<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"403219","marker":{"color":"rgb(0, 172, 198)","size":[0.0],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"403219","orientation":"v","showlegend":true,"type":"scatter","x":[-1.0005000829696655],"xaxis":"x","y":[2.923426389694214],"yaxis":"y"},{"hovertemplate":"id=326318<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"326318","marker":{"color":"rgb(230, 165, 0)","size":[0.612510621547699],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"326318","orientation":"v","showlegend":true,"type":"scatter","x":[-1.2615000009536743],"xaxis":"x","y":[0.9162977933883667],"yaxis":"y"},{"hovertemplate":"id=330102<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"330102","marker":{"color":"rgb(255, 126, 209)","size":[0.24478544294834137],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"330102","orientation":"v","showlegend":true,"type":"scatter","x":[-1.2615001201629639],"xaxis":"x","y":[1.1780972480773926],"yaxis":"y"},{"hovertemplate":"id=389543<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"389543","marker":{"color":"rgb(107, 0, 79)","size":[0.06719726324081421],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"389543","orientation":"v","showlegend":true,"type":"scatter","x":[-1.34850013256073],"xaxis":"x","y":[-1.3526298999786377],"yaxis":"y"},{"hovertemplate":"id=181<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"181","marker":{"color":"rgb(87, 59, 0)","size":[0.30219534039497375,0.5664379000663757,0.32326775789260864],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"181","orientation":"v","showlegend":true,"type":"scatter","x":[0.04349999874830246,0.04349999874830246,0.04349999874830246],"xaxis":"x","y":[-1.7016961574554443,-1.7889626026153564,-1.876229166984558 ...

# %%
px.scatter(plot_df, x='eta_pred', y='phi_pred', size='energy', color='id', color_discrete_sequence=get_palette(plot_df['id']))
# Out:
# <div>                            <div id="2edb9929-cb54-4c51-b378-1e9891a05515" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2edb9929-cb54-4c51-b378-1e9891a05515")) {                    Plotly.newPlot(                        "2edb9929-cb54-4c51-b378-1e9891a05515",                        [{"hovertemplate":"id=302137<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"302137","marker":{"color":"rgb(214, 0, 0)","size":[0.003629842074587941,0.0],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"302137","orientation":"v","showlegend":true,"type":"scatter","x":[-0.16167040169239044,-0.19502125680446625],"xaxis":"x","y":[-2.052037477493286,-2.051382064819336],"yaxis":"y"},{"hovertemplate":"id=401032<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"401032","marker":{"color":"rgb(140, 59, 255)","size":[0.5512226819992065],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"401032","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8283884525299072],"xaxis":"x","y":[-1.789706826210022],"yaxis":"y"},{"hovertemplate":"id=359378<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"359378","marker":{"color":"rgb(1, 135, 0)","size":[0.17138375341892242,0.2544173002243042],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"359378","orientation":"v","showlegend":true,"type":"scatter","x":[-0.9449339509010315,-0.9773240685462952],"xaxis":"x","y":[2.573087692260742,2.573753833770752],"yaxis":"y"},{"hovertemplate":"id=403219<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"403219","marker":{"color":"rgb(0, 172, 198)","size":[0.0],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"403219","orientation":"v","showlegend":true,"type":"scatter","x":[-1.0023884773254395],"xaxis":"x","y":[2.922682285308838],"yaxis":"y"},{"hovertemplate":"id=326318<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"326318","marker":{"color":"rgb(230, 165, 0)","size":[0.612510621547699],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"326318","orientation":"v","showlegend":true,"type":"scatter","x":[-1.2633883953094482],"xaxis":"x","y":[0.9155536890029907],"yaxis":"y"},{"hovertemplate":"id=330102<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"330102","marker":{"color":"rgb(255, 126, 209)","size":[0.24478544294834137],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"330102","orientation":"v","showlegend":true,"type":"scatter","x":[-1.2633920907974243],"xaxis":"x","y":[1.1784566640853882],"yaxis":"y"},{"hovertemplate":"id=389543<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"389543","marker":{"color":"rgb(107, 0, 79)","size":[0.06719726324081421],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"389543","orientation":"v","showlegend":true,"type":"scatter","x":[-1.350388526916504],"xaxis":"x","y":[-1.3533740043640137],"yaxis":"y"},{"hovertemplate":"id=181<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"181","marker":{"color":"rgb(87, 59, 0)","size":[0.30219534039497375,0.5664379000663757,0.32326775789260864],"sizemode":"area","sizeref":0.006676289439201355,"symbol":"circle"},"mode":"markers","name":"181","orientation":"v","showlegend":true,"type":"scatter","x":[0.04230782762169838,0.04166155308485031,0.04103606194257 ...

# %%
# true semantic labels, pred instance labels from coordinates
clusterer = MeanShift(bandwidth=bw, use_semantic=True, ignore_semantic_labels=(0,))

# %%
n = 7
evt = events[n]
d = {'eta': evt.input_event['eta'], 'phi': evt.input_event['phi'], 'energy': evt.input_event['energy'], 'hit': evt.input_event['hit'], 'id': evt.pred_instance_labels, 'eta_pred': evt.embedding[:,0], 'phi_pred': evt.embedding[:,1]}
plot_df = pd.DataFrame(d)
plot_df['id'] = plot_df['id'].astype(str)
plot_df = plot_df[plot_df['hit'] == 1]

# %%
px.scatter(plot_df, x='eta_pred', y='phi_pred', size='energy', color='id', color_discrete_sequence=get_palette(plot_df['id']))
# Out:
# <div>                            <div id="77a377d2-7733-4de4-9497-aabf252fd21a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77a377d2-7733-4de4-9497-aabf252fd21a")) {                    Plotly.newPlot(                        "77a377d2-7733-4de4-9497-aabf252fd21a",                        [{"hovertemplate":"id=17<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"17","marker":{"color":"rgb(214, 0, 0)","size":[0.030784782022237778],"sizemode":"area","sizeref":0.013553987741470336,"symbol":"circle"},"mode":"markers","name":"17","orientation":"v","showlegend":true,"type":"scatter","x":[-0.13238835334777832],"xaxis":"x","y":[-1.4406406879425049],"yaxis":"y"},{"hovertemplate":"id=20<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"20","marker":{"color":"rgb(140, 59, 255)","size":[0.07232224941253662],"sizemode":"area","sizeref":0.013553987741470336,"symbol":"circle"},"mode":"markers","name":"20","orientation":"v","showlegend":true,"type":"scatter","x":[-0.4803900718688965],"xaxis":"x","y":[0.7409642338752747],"yaxis":"y"},{"hovertemplate":"id=19<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"19","marker":{"color":"rgb(1, 135, 0)","size":[0.1819736361503601],"sizemode":"area","sizeref":0.013553987741470336,"symbol":"circle"},"mode":"markers","name":"19","orientation":"v","showlegend":true,"type":"scatter","x":[-0.4802457392215729],"xaxis":"x","y":[-0.13202175498008728],"yaxis":"y"},{"hovertemplate":"id=23<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"23","marker":{"color":"rgb(0, 172, 198)","size":[0.10620689392089844],"sizemode":"area","sizeref":0.013553987741470336,"symbol":"circle"},"mode":"markers","name":"23","orientation":"v","showlegend":true,"type":"scatter","x":[-0.7412959933280945],"xaxis":"x","y":[0.6534359455108643],"yaxis":"y"},{"hovertemplate":"id=3<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"3","marker":{"color":"rgb(230, 165, 0)","size":[0.2571072578430176,0.2968598008155823,0.38556569814682007,1.3889292478561401],"sizemode":"area","sizeref":0.013553987741470336,"symbol":"circle"},"mode":"markers","name":"3","orientation":"v","showlegend":true,"type":"scatter","x":[-0.7413883805274963,-0.7413883805274963,-0.7413883805274963,-0.7413883805274963],"xaxis":"x","y":[-2.7496376037597656,-2.7496376037597656,-2.7496376037597656,-2.7496376037597656],"yaxis":"y"},{"hovertemplate":"id=0<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"0","marker":{"color":"rgb(255, 126, 209)","size":[0.5683659315109253,0.5615128874778748,3.039388418197632,0.48220303654670715,4.213519096374512,0.49813154339790344,1.9726516008377075,1.0934836864471436,0.4304349720478058,0.5677461624145508,0.02038443461060524],"sizemode":"area","sizeref":0.013553987741470336,"symbol":"circle"},"mode":"markers","name":"0","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8281967043876648,-0.8280016183853149,-0.9149090647697449,-0.8281967043876648,-0.8280016183853149,-0.8281967043876648,-0.9151986241340637,-0.9149090647697449,-0.8280016183853149,-0.9151986241340637,-0.9151986241340637],"xaxis":"x","y":[0.04238143190741539,0.12913097441196442,0.1288856565952301,0.04238143190741539,0.12913097441196442,0.04238143190741539,0.04238594323396683,0.1288856565952301,0.12913097441196442,0.04238594323396683,0.04238594323396683],"yaxis":"y"},{"hovertemplate":"id=1<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"1","marker":{"color":"rgb(107, 0, 79)","size":[0.4730207324028015,3.268286943435669],"sizemode":"area","sizeref":0.01355398774147033 ...

# %%
n = 6
evt = events[n]
d = {'eta': evt.input_event['eta'], 'phi': evt.input_event['phi'], 'energy': evt.input_event['energy'], 'hit': evt.input_event['hit'], 'id': evt.input_event['PFcluster0Id'], 'eta_pred': evt.embedding[:,0], 'phi_pred': evt.embedding[:,1]}
plot_df = pd.DataFrame(d)
plot_df['id'] = plot_df['id'].astype(str)
plot_df = plot_df[plot_df['hit'] == 1]

# %%
px.scatter(plot_df, x='eta', y='phi', size='energy', color='id', color_discrete_sequence=get_palette(plot_df['id']))

# %%
events = exp.get_events(split='test', n=-1)
# Out:
#   0%|          | 0/106804 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28166/3870041670.py in <module>
# ----> 1 events = exp.get_events(split='test', n=-1)
#
# /global/u2/s/schuya/calo-cluster/calo_cluster/evaluation/experiments/base_experiment.py in get_events(self, split, n, batch_size)
#     195             event_name = input_path.stem
#     196             pred_path = pred_dir / f'{event_name}.npz'
# --> 197             events.append(self.make_event(
#     198                 input_path, pred_path))
#     199         return events
#
# /global/u2/s/schuya/calo-cluster/calo_cluster/evaluation/experiments/base_experiment.py in make_event(self, input_path, pred_path)
#     200
#     201     def make_event(self, input_path, pred_path):
# --> 202         return BaseEvent(input_path, pred_path, self.task)
#     203
#     204     def load_model(self, ckpt_path):
#
# /global/u2/s/schuya/calo-cluster/calo_cluster/evaluation/experiments/base_experiment.py in __init__(self, input_path, pred_path, task)
#      36         self.task = task
#      37         self._pred_instance_labels = None
# ---> 38         self._load()
#      39
#      40     def _load(self):
#
# /global/u2/s/schuya/calo-cluster/calo_cluster/evaluation/experiments/base_experiment.py in _load(self)
#      39
#      40     def _load(self):
# ---> 41         self.input_event = self._load_input()
#      42         self._load_predictions()
#      43
#
# /global/u2/s/schuya/calo-cluster/calo_cluster/evaluation/experiments/base_experiment.py in _load_input(self)
#      43
#      44     def _load_input(self):
# ---> 45         input_event = pd.read_pickle(self.input_path)
#      46         return input_event
#      47
#
# ~/miniconda3/envs/calo_cluster/lib/python3.8/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     215                     # RawIOBase, BufferedIOBase, TextIOBase, TextIOWrapper, mmap]";
#     216                     # expected "IO[bytes]"
# --> 217                     return pickle.load(handles.handle)  # type: ignore[arg-type]
#     218             except excs_to_catch:
#     219                 # e.g.
#
# ~/miniconda3/envs/calo_cluster/lib/python3.8/site-packages/numpy/core/numeric.py in _frombuffer(buf, dtype, shape, order)
#    1852
#    1853
# -> 1854 def _frombuffer(buf, dtype, shape, order):
#    1855     return frombuffer(buf, dtype=dtype).reshape(shape, order=order)
#    1856
#
# KeyboardInterrupt:

# %%
clusterer = MeanShift(bandwidth=0.1, use_semantic=True, ignore_semantic_labels=(0,), use_gpu=False)
for evt in tqdm(events):
    semantic_truth = evt.input_event['hit'].to_numpy()
    evt.pred_instance_labels = clusterer.cluster(embedding=evt.embedding, semantic_labels=semantic_truth)
outputs = [(evt.input_event['hit'].to_numpy(), evt.pred_instance_labels) for evt in events]
targets = [(evt.input_event['hit'].to_numpy(), evt.input_event['trackId'].to_numpy()) for evt in events]
weights = [evt.input_event['genE'].to_numpy() for evt in events]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from calo_cluster.evaluation.studies.functional import response
cluster_response, event_response = response(outputs, targets, weights, match_highest=False, num_classes=2, ignore_semantic_labels=(0,))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
cluster_response[1]['energy response']
# Out:
# 0       1.755943
# 1       1.000000
# 2       1.000000
# 3       1.000000
# 4       1.932101
#           ...
# 2238    1.000000
# 2239    1.000000
# 2240    1.000000
# 2241    0.000000
# 2242    0.000000
# Name: energy response, Length: 2243, dtype: float64

# %%
unmatched_mask = cluster_response[1]['energy response'] == 0.0
unmatched_energy = cluster_response[1].loc[unmatched_mask, 'energy']
matched_energy = cluster_response[1].loc[~unmatched_mask, 'energy']
unmatched_hist, bin_edges = np.histogram(unmatched_energy, bins=20, range=(0, 10))
matched_hist, _ = np.histogram(matched_energy, bins=20, range=(0, 10))
efficiency = matched_hist / (matched_hist + unmatched_hist)
x = [(bin_edges[i] + bin_edges[i+1]) / 2 for i in range(len(bin_edges) - 1)]
px.scatter(y=efficiency, x=x)
# Out:
# <div>                            <div id="726364c7-65b3-4c01-ae42-c4d6ed564bcf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("726364c7-65b3-4c01-ae42-c4d6ed564bcf")) {                    Plotly.newPlot(                        "726364c7-65b3-4c01-ae42-c4d6ed564bcf",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"type":"scatter","x":[0.25,0.75,1.25,1.75,2.25,2.75,3.25,3.75,4.25,4.75,5.25,5.75,6.25,6.75,7.25,7.75,8.25,8.75,9.25,9.75],"xaxis":"x","y":[0.7644110275689223,0.745253164556962,0.7397260273972602,0.764367816091954,0.7373737373737373,0.8666666666666667,0.6956521739130435,0.7777777777777778,0.5714285714285714,0.8666666666666667,0.8181818181818182,0.9,0.6666666666666666,0.75,0.7272727272727273,1.0,0.6666666666666666,0.25,1.0,0.6],"yaxis":"y"}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"me ...

# %%
import plotly.graph_objects as go
import plotly
fig = go.Figure()
bar = go.Bar(x=x, y=efficiency, name='efficiency', )
fig.add_trace(bar)
fig.update_layout(bargap=0.0, bargroupgap=0.0)
fig.show()
# Out:
# <div>                            <div id="ff1e42e2-aa4c-4acc-9e81-0471ede77dd1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff1e42e2-aa4c-4acc-9e81-0471ede77dd1")) {                    Plotly.newPlot(                        "ff1e42e2-aa4c-4acc-9e81-0471ede77dd1",                        [{"name":"efficiency","type":"bar","x":[0.25,0.75,1.25,1.75,2.25,2.75,3.25,3.75,4.25,4.75,5.25,5.75,6.25,6.75,7.25,7.75,8.25,8.75,9.25,9.75],"y":[0.7452316076294278,0.7660377358490567,0.8024193548387096,0.8283582089552238,0.8181818181818182,0.8382352941176471,0.8636363636363636,0.7428571428571429,0.7619047619047619,1.0,1.0,0.9,0.7,0.4,0.75,0.75,1.0,1.0,0.3333333333333333,0.6666666666666666]}],                        {"bargap":0.0,"bargroupgap":0.0,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0," ...

# %%
n = 4
evt = events[n]
d = {'eta': evt.input_event['eta'], 'phi': evt.input_event['phi'], 'energy': evt.input_event['energy'], 'hit': evt.input_event['hit'], 'id': evt.input_event['trackId'], 'pred_id': evt.pred_instance_labels, 'eta_pred': evt.embedding[:,0], 'phi_pred': evt.embedding[:,1]}
plot_df = pd.DataFrame(d)
plot_df['id'] = plot_df['id'].astype(str)
plot_df['pred_id'] = plot_df['pred_id'].astype(str)
plot_df = plot_df[plot_df['hit'] == 1]

# %%
px.scatter(plot_df, x='eta', y='phi', size='energy', color='id', color_discrete_sequence=get_palette(plot_df['id']))
# Out:
# <div>                            <div id="ddffd5d6-a053-4665-9742-125dc3cd081f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddffd5d6-a053-4665-9742-125dc3cd081f")) {                    Plotly.newPlot(                        "ddffd5d6-a053-4665-9742-125dc3cd081f",                        [{"hovertemplate":"id=239449<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"239449","marker":{"color":"rgb(214, 0, 0)","size":[0.2216927409172058],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"239449","orientation":"v","showlegend":true,"type":"scatter","x":[-0.39149996638298035],"xaxis":"x","y":[-2.4870944023132324],"yaxis":"y"},{"hovertemplate":"id=382720<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"382720","marker":{"color":"rgb(140, 59, 255)","size":[0.0968930646777153],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"382720","orientation":"v","showlegend":true,"type":"scatter","x":[-0.565500020980835],"xaxis":"x","y":[2.225294828414917],"yaxis":"y"},{"hovertemplate":"id=382371<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"382371","marker":{"color":"rgb(1, 135, 0)","size":[0.10650165379047394],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"382371","orientation":"v","showlegend":true,"type":"scatter","x":[-0.5654999613761902],"xaxis":"x","y":[2.4870941638946533],"yaxis":"y"},{"hovertemplate":"id=380756<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"380756","marker":{"color":"rgb(0, 172, 198)","size":[0.33041906356811523],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"380756","orientation":"v","showlegend":true,"type":"scatter","x":[-0.6524999141693115],"xaxis":"x","y":[2.312561273574829],"yaxis":"y"},{"hovertemplate":"id=230752<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"230752","marker":{"color":"rgb(230, 165, 0)","size":[0.29056626558303833,1.8194197416305542],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"230752","orientation":"v","showlegend":true,"type":"scatter","x":[-0.6524999737739563,-0.565500020980835],"xaxis":"x","y":[2.4870941638946533,2.5743606090545654],"yaxis":"y"},{"hovertemplate":"id=207449<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"207449","marker":{"color":"rgb(255, 126, 209)","size":[0.06593262404203415],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"207449","orientation":"v","showlegend":true,"type":"scatter","x":[-0.6524999737739563],"xaxis":"x","y":[-2.6616270542144775],"yaxis":"y"},{"hovertemplate":"id=381164<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"381164","marker":{"color":"rgb(107, 0, 79)","size":[0.2518157660961151,0.7271451354026794],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"381164","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8264999389648438,-0.8265000581741333],"xaxis":"x","y":[2.138028144836426,2.138028383255005],"yaxis":"y"},{"hovertemplate":"id=381168<br>eta=%{x}<br>phi=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"381168","marker":{"color":"rgb(87, 59, 0)","size":[1.1435351371765137],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"381168","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8264999389648438],"xaxis":"x","y":[2.225294828414917],"yaxis":"y"},{"hovertemplate":"id=380729<br>eta=%{x}<br>phi=%{y}<br>energy=%{marke ...

# %%
px.scatter(plot_df, x='eta_pred', y='phi_pred', size='energy', color='pred_id', color_discrete_sequence=get_palette(plot_df['pred_id']))
# Out:
# <div>                            <div id="d43cd411-ab00-4b32-90e9-7f84f95de702" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d43cd411-ab00-4b32-90e9-7f84f95de702")) {                    Plotly.newPlot(                        "d43cd411-ab00-4b32-90e9-7f84f95de702",                        [{"hovertemplate":"pred_id=25<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"25","marker":{"color":"rgb(214, 0, 0)","size":[0.2216927409172058],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"25","orientation":"v","showlegend":true,"type":"scatter","x":[-0.39149996638298035],"xaxis":"x","y":[-2.4870944023132324],"yaxis":"y"},{"hovertemplate":"pred_id=26<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"26","marker":{"color":"rgb(140, 59, 255)","size":[0.0968930646777153],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"26","orientation":"v","showlegend":true,"type":"scatter","x":[-0.565500020980835],"xaxis":"x","y":[2.225294828414917],"yaxis":"y"},{"hovertemplate":"pred_id=2<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"2","marker":{"color":"rgb(1, 135, 0)","size":[0.10650165379047394,0.33041906356811523,0.29056626558303833,1.8194197416305542],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"2","orientation":"v","showlegend":true,"type":"scatter","x":[-0.5654999613761902,-0.5654999613761902,-0.5654999613761902,-0.565500020980835],"xaxis":"x","y":[2.4870941638946533,2.4870941638946533,2.4870941638946533,2.5743606090545654],"yaxis":"y"},{"hovertemplate":"pred_id=27<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"27","marker":{"color":"rgb(0, 172, 198)","size":[0.06593262404203415],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"27","orientation":"v","showlegend":true,"type":"scatter","x":[-0.6524999737739563],"xaxis":"x","y":[-2.6616270542144775],"yaxis":"y"},{"hovertemplate":"pred_id=4<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"4","marker":{"color":"rgb(230, 165, 0)","size":[0.2518157660961151,1.1435351371765137,0.7271451354026794],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"4","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8264999389648438,-0.8264999389648438,-0.8264999389648438],"xaxis":"x","y":[2.138028144836426,2.138028144836426,2.138028144836426],"yaxis":"y"},{"hovertemplate":"pred_id=28<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"28","marker":{"color":"rgb(255, 126, 209)","size":[0.0],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"28","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8264999389648438],"xaxis":"x","y":[2.399827718734741],"yaxis":"y"},{"hovertemplate":"pred_id=12<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"12","marker":{"color":"rgb(107, 0, 79)","size":[0.055860042572021484,0.26801031827926636],"sizemode":"area","sizeref":0.009039021134376525,"symbol":"circle"},"mode":"markers","name":"12","orientation":"v","showlegend":true,"type":"scatter","x":[-0.8264999389648438,-0.8264999389648438],"xaxis":"x","y":[3.010693073272705,3.010693073272705],"yaxis":"y"},{"hovertemplate":"pred_id=5<br>eta_pred=%{x}<br>phi_pred=%{y}<br>energy=%{marker.size}<extra></extra>","legendgroup":"5","marker":{"color":"rgb(87, 59, 0)","size":[0.2056950181722641,0.453144371509552,3.6156084537506104],"sizemode":"area","sizer ...

# %%
evt.input_event['hit'].unique()
# Out:
# array([1, 0])

# %%
unique_labels = set()
for evt in events:
    for f in evt.input_event['hit'].unique():
        unique_labels.add(f)

# %%
unique_labels
# Out:
# {0, 1}
